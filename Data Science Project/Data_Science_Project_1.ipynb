# %% [markdown]
# # Data Analysis and Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read and Display Initial Data

# %% [markdown]
# Reading a CSV file and displaying the first 10 rows of the DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = '/content/drive/MyDrive/Colab Notebooks/Mobile_phone_price.csv'
df = pd.read_csv(file)

# %%
df.head(10)
# Out:
#      Brand              Model Storage    RAM  Screen Size (inches)  \
# 0    Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1  Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2  OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3   Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4   Google            Pixel 6   128 GB   8 GB                  6.4
# 5    Apple          iPhone 13   128 GB   4 GB                  6.1
# 6  Samsung     Galaxy Z Flip3   256 GB   8 GB                  6.7
# 7   Xiaomi        Poco X3 Pro   128 GB   6 GB                 6.67
# 8     Oppo      Reno6 Pro+ 5G   128 GB   8 GB                 6.55
# 9     Vivo           X70 Pro+   256 GB  12 GB                 6.78
#
#           Camera (MP)  Battery Capacity (mAh) Price ($)
# 0        12 + 12 + 12                    3095       999
# 1  108 + 10 + 10 + 12                    5000      1199
# 2     48 + 50 + 8 + 2                    4500       899
# ...

# %% [markdown]
# ## DataFrame Dimensions

# %% [markdown]
# Displaying the dimensions of the DataFrame (number of rows and columns)

# %%
df_shape = df.shape
df_shape
# Out:
# (407, 8)

# %% [markdown]
# ## Unique Values in 'RAM' Column

# %% [markdown]
# Displaying unique values in the 'RAM' column

# %%
unique_ram_values = df['RAM '].unique()
unique_ram_values
# Out:
# array(['6 GB', '12 GB', '8 GB', '4 GB', '3 GB', '2 GB', '4GB', '8GB',
#        '6GB', '12GB', '3GB', '2GB', '5GB', '12', '3', '6', '8', '4', '16',
#        '2'], dtype=object)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='RAM ', data=df, palette='viridis')
plt.title('Jumlah Ponsel untuk Setiap Tipe RAM')
plt.show()

# %% [markdown]
# ## General DataFrame Information

# %% [markdown]
# Displaying general information about the DataFrame, including data types and non-null counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 25.6+ KB

# %% [markdown]
# ## Descriptive Statistics for Numeric Columns

# %% [markdown]
# Displaying descriptive statistics for numeric columns

# %%
df_describe = df.describe()
df_describe
# Out:
#        Battery Capacity (mAh)
# count              407.000000
# mean              4676.476658
# std                797.193713
# min               1821.000000
# 25%               4300.000000
# 50%               5000.000000
# 75%               5000.000000
# max               7000.000000

# %%
plt.figure(figsize=(12, 8))
sns.histplot(df['Battery Capacity (mAh)'], bins=20, kde=True, color='skyblue')
plt.title('Distribusi Kapasitas Baterai')
plt.xlabel('Battery Capacity (mAh)')
plt.show()

# %% [markdown]
# ## Handling Null Values

# %% [markdown]
# Displaying the count of null values in each column

# %%
df.isna().sum()
# Out:
# Brand                     0
# Model                     0
# Storage                   0
# RAM                       0
# Screen Size (inches)      0
# Camera (MP)               0
# Battery Capacity (mAh)    0
# Price ($)                 0
# dtype: int64

# %% [markdown]
# ## Handling Unique Values

# %% [markdown]
# Displaying the count of unique values in each column

# %%
df.nunique()
# Out:
# Brand                      16
# Model                     239
# Storage                    13
# RAM                        20
# Screen Size (inches)       41
# Camera (MP)               143
# Battery Capacity (mAh)     48
# Price ($)                  89
# dtype: int64

# %%
# Menampilkan nilai unik dari kolom 'Price ($)'
df['Price ($)'].unique()
# Out:
# array(['999', '1199', '899', '279', '799', '249', '699', '329', '449',
#        '199', '299', '379', '179', '729', '599', '139', '189', '399',
#        '259', '159', '229', '499', '129', '529', '369', '1099', '169',
#        '99', '459', '239', '1299', '429', '659', '269', '359', '$799 ',
#        '$399 ', '$699 ', '$329 ', '$999 ', '$549 ', '$1,299 ', '$899 ',
#        '$449 ', '$319 ', '$269 ', '$349 ', '$279 ', '$249 ', '$299 ',
#        '$969 ', '$1,199 ', '$149 ', '$139 ', '$99 ', '$199 ', '$169 ',
#        '$499 ', '$179 ', '$219 ', '$229 ', '$239 ', '$109 ', '$189 ',
#        '$389 ', '$309 ', '$369 ', '$129 ', '$849 ', '$469 ', '$209 ',
#        '$119 ', '$339 ', '$429 ', '$159 ', '$379 ', '$289 ', '130', '749',
#        '149', '969', '649', '349', '419', '1399', '1999', '119', '319',
#        '1049'], dtype=object)

# %%
# Menampilkan nilai unik dari kolom "Screen Size (inches)"
df["Screen Size (inches)"].unique()
# Out:
# array(['6.1', '6.8', '6.7', '6.67', '6.4', '6.55', '6.78', '6.43', '6.5',
#        '6.62', '5.4', '6.2', '6.51', '6.6', '4.7', '6.58', '6.52', '6.44',
#        '6.53', '6.56', '6.8 + 3.9', '4.5', '6.39', '5.9', '5.5', '6.81',
#        '5.99', '6.82', '6.3', '6.22', '6', '6.35', '6.9', '6.76', '6.49',
#        '6.72', '5.7', '6.47', '7.6 (unfolded)', '6.15', '6.57'],
#       dtype=object)

# %%
# Menampilkan baris DataFrame dengan 'Screen Size (inches)' sama dengan '6.8 + 3.9'
df[df['Screen Size (inches)'] == '6.8 + 3.9']
# Out:
#    Brand Model Storage  RAM  Screen Size (inches)         Camera (MP)  \
# 88    LG  Wing    256GB  8GB            6.8 + 3.9  64MP + 13MP + 12MP
#
#     Battery Capacity (mAh) Price ($)
# 88                    4000     $999

# %%
# Menampilkan baris DataFrame dengan 'Screen Size (inches)' sama dengan '7.6 (unfolded)'
df[df['Screen Size (inches)'] == '7.6 (unfolded)']
# Out:
#        Brand              Model Storage  RAM  Screen Size (inches)  \
# 373  Samsung  Galaxy Z Fold2 5G      256   12       7.6 (unfolded)
#
#     Camera (MP)  Battery Capacity (mAh) Price ($)
# 373    12+12+12                    4500      1999

# %%
# Menampilkan baris DataFrame di mana nilai dalam kolom 'Price ($)' bukan numerik
df[~df['Price ($)'].str.isnumeric()]
# Out:
#        Brand        Model Storage  RAM  Screen Size (inches)  \
# 77     Apple    iPhone 13    128GB  4GB                  6.1
# 78   Samsung   Galaxy S21    128GB  8GB                  6.2
# 79   OnePlus       Nord 2    128GB  8GB                 6.43
# 80    Google      Pixel 6    128GB  8GB                  6.4
# 81    Xiaomi  Poco X4 Pro    128GB  6GB                 6.67
# ..       ...          ...      ...  ...                  ...
# 283     Oppo          A31    128GB  4GB                  6.5
# 284     Vivo          Y15     64GB  4GB                 6.35
# 285   Realme    Narzo 10A     32GB  3GB                  6.5
# 286   Xiaomi     Redmi 9T    128GB  4GB                 6.53
# 287  Samsung  Galaxy A30s     64GB  4GB                  6.4
#
#                 Camera (MP)  Battery Capacity (mAh) Price ($)
# 77              12MP + 12MP                    2815     $799
# 78       64MP + 12MP + 12MP                    4000     $799
# ...

# %% [markdown]
# ## Cleaning 'Price ($)'

# %% [markdown]
# Cleaning the 'Price ($)' column by removing symbols and converting it to integer

# %%
#cleaning
df['Price ($)'] = df['Price ($)'].str.replace('$','')
df['Price ($)'] = df['Price ($)'].str.replace(',','')
df['Price ($)'] = df['Price ($)'].str.replace(' ','')
df['Price ($)'] = df['Price ($)'].astype(int)
# Menampilkan ringkasan statistik deskriptif setelah membersihkan kolom 'Price ($)'
df.describe()
# Out:
# <ipython-input-18-70f34a0adad3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price ($)'] = df['Price ($)'].str.replace('$','')
#        Battery Capacity (mAh)    Price ($)
# count              407.000000   407.000000
# mean              4676.476658   408.314496
# std                797.193713   299.684768
# min               1821.000000    99.000000
# 25%               4300.000000   199.000000
# 50%               5000.000000   299.000000
# 75%               5000.000000   499.000000
# max               7000.000000  1999.000000

# %%
# Menampilkan informasi umum DataFrame setelah pembersihan
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Brand                   407 non-null    object
#  1   Model                   407 non-null    object
#  2   Storage                 407 non-null    object
#  3   RAM                     407 non-null    object
#  4   Screen Size (inches)    407 non-null    object
#  5   Camera (MP)             407 non-null    object
#  6   Battery Capacity (mAh)  407 non-null    int64
#  7   Price ($)               407 non-null    int64
# dtypes: int64(2), object(6)
# memory usage: 25.6+ KB

# %%
# Menampilkan nilai unik dari kolom 'Price ($) setelah dibersihkan'
df['Price ($)'].unique()
# Out:
# array([ 999, 1199,  899,  279,  799,  249,  699,  329,  449,  199,  299,
#         379,  179,  729,  599,  139,  189,  399,  259,  159,  229,  499,
#         129,  529,  369, 1099,  169,   99,  459,  239, 1299,  429,  659,
#         269,  359,  549,  319,  349,  969,  149,  219,  109,  389,  309,
#         849,  469,  209,  119,  339,  289,  130,  749,  649,  419, 1399,
#        1999, 1049])

# %% [markdown]
# # Further Data Analysis

# %% [markdown]
# ## Regular Expression for String Cleaning

# %% [markdown]
# Using regular expressions to clean values in strings

# %%
# Menggunakan ekspresi reguler untuk menghapus karakter non-digit dari string
import re

# %%
s = '$1,29.9'
s = re.sub('\D', '', s)
s
# Out:
# '1299'

# %% [markdown]
# ## Descriptive Statistics for Numeric Series

# %% [markdown]
# Displaying descriptive statistics for a numeric Series

# %%
# Seri numerik: Menyajikan statistik deskriptif untuk melihat ringkasan data
s = pd.Series([1, 2, 3, 4, 5, 6, 7, 8, 9])
s.describe()
# Out:
# count    9.000000
# mean     5.000000
# std      2.738613
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      7.000000
# max      9.000000
# dtype: float64

# %%
df['RAM '].unique()
# Out:
# array(['6 GB', '12 GB', '8 GB', '4 GB', '3 GB', '2 GB', '4GB', '8GB',
#        '6GB', '12GB', '3GB', '2GB', '5GB', '12', '3', '6', '8', '4', '16',
#        '2'], dtype=object)

# %% [markdown]
# ## Cleaning and Type Conversion of 'RAM ' Column

# %% [markdown]
# Cleaning and converting the data in the 'RAM ' column

# %%
# Membersihkan nilai pada kolom 'RAM ' dengan menghapus karakter selain digit
#df['RAM'] = df['RAM'].str.replace('GB','')
#df['RAM'] = df['RAM'].str.replace(' GB','')
#df['RAM '] = df['RAM '].astype(int)
df['RAM '] = df['RAM '].str.replace('[^0-9]', '', regex = True)
df['RAM '] = df['RAM '].astype(int)
df.describe()
# Out:
#              RAM   Battery Capacity (mAh)    Price ($)
# count  407.000000              407.000000   407.000000
# mean     5.837838             4676.476658   408.314496
# std      2.431980              797.193713   299.684768
# min      2.000000             1821.000000    99.000000
# 25%      4.000000             4300.000000   199.000000
# 50%      6.000000             5000.000000   299.000000
# 75%      8.000000             5000.000000   499.000000
# max     16.000000             7000.000000  1999.000000

# %%
# Menampilkan nilai unik dari kolom RAM setelah dibersihkan'
df['RAM '].unique()
# Out:
# array([ 6, 12,  8,  4,  3,  2,  5, 16])

# %% [markdown]
# ## Sorting and Filtering Data

# %% [markdown]
# Sorting the DataFrame based on multiple columns and applying filters

# %%
# Mengurutkan DataFrame berdasarkan 'Battery Capacity (mAh)' secara ascending
df.sort_values(by = ['Battery Capacity (mAh)'])
# Out:
#        Brand                Model Storage   RAM  Screen Size (inches)  \
# 289    Apple     iPhone SE (2020)       64     3                  4.7
# 32     Apple  iPhone SE (2nd Gen)    64 GB     3                  4.7
# 379    Apple     iPhone SE (2020)      128     3                  4.7
# 333    Apple     iPhone SE (2020)       64     3                  4.7
# 62     Apple     iPhone SE (2020)    64 GB     3                  4.7
# ..       ...                  ...      ...   ...                  ...
# 286   Xiaomi             Redmi 9T    128GB     4                 6.53
# 175   Realme                 C25s    128GB     4                  6.5
# 236  Samsung           Galaxy M12     64GB     4                  6.5
# 208  Samsung           Galaxy M62    128GB     8                  6.7
# 334  Samsung           Galaxy M51      128     6                  6.7
#
#                  Camera (MP)  Battery Capacity (mAh)  Price ($)
# ...

# %%
# Mengurutkan DataFrame berdasarkan 'Battery Capacity (mAh)' dan 'Price ($)' secara bersamaan
df.sort_values(by = ['Battery Capacity (mAh)', 'Price ($)'], ascending = [True, False])
#df.sort_values(by = ['Battery Capacity (mAh)', 'Price ($)'], ascending = [True, True])
# Out:
#         Brand                Model Storage   RAM  Screen Size (inches)  \
# 379     Apple     iPhone SE (2020)      128     3                  4.7
# 32      Apple  iPhone SE (2nd Gen)    64 GB     3                  4.7
# 62      Apple     iPhone SE (2020)    64 GB     3                  4.7
# 289     Apple     iPhone SE (2020)       64     3                  4.7
# 333     Apple     iPhone SE (2020)       64     3                  4.7
# ..        ...                  ...      ...   ...                  ...
# 198  Motorola   Moto G9 Power Lite     64GB     4                  6.5
# 217     Nokia                  C30     32GB     2                 6.82
# 397    Xiaomi              Poco M3      128     4                 6.53
# 334   Samsung           Galaxy M51      128     6                  6.7
# 208   Samsung           Galaxy M62    128GB     8                  6.7
#
#                  Camera (MP)  Battery Capacity (mAh)  Price ($)
# ...

# %%
# Memilih 5 entri teratas dengan 'Battery Capacity (mAh)' terbesar
df.nlargest(5, 'Battery Capacity (mAh)')
# Out:
#        Brand           Model Storage   RAM  Screen Size (inches)  \
# 208  Samsung      Galaxy M62    128GB     8                  6.7
# 334  Samsung      Galaxy M51      128     6                  6.7
# 20    Xiaomi  Redmi 10 Prime   128 GB     6                  6.5
# 29    Realme              9i   128 GB     4                  6.5
# 35    Realme            C25s   128 GB     4                  6.5
#
#                  Camera (MP)  Battery Capacity (mAh)  Price ($)
# 208  64MP + 12MP + 5MP + 5MP                    7000        429
# 334                64+12+5+5                    7000        449
# 20            50 + 8 + 2 + 2                    6000        179
# 29                50 + 2 + 2                    6000        189
# 35                13 + 2 + 2                    6000        159

# %%
df.loc[df['Brand'] == 'Xiaomi']
#df.loc[df['Brand'] == 'Xiaomi') & (df['Price ($')]<=600), ['Brand'], ['Model'],['Price ($)']]
# Out:
#       Brand                  Model Storage   RAM  Screen Size (inches)  \
# 3    Xiaomi      Redmi Note 10 Pro   128 GB     6                 6.67
# 7    Xiaomi            Poco X3 Pro   128 GB     6                 6.67
# 15   Xiaomi       Mi 11 Lite 5G NE   128 GB     6                 6.55
# 20   Xiaomi         Redmi 10 Prime   128 GB     6                  6.5
# 24   Xiaomi  Redmi Note 10 Pro Max   128 GB     6                 6.67
# ..      ...                    ...      ...   ...                  ...
# 380  Xiaomi               Redmi 9C       64     3                 6.53
# 386  Xiaomi      Redmi Note 10 Pro      128     6                 6.67
# 389  Xiaomi               Redmi 9T      128     4                 6.53
# 397  Xiaomi                Poco M3      128     4                 6.53
# 403  Xiaomi          Mi 10 Lite 5G      128     6                 6.57
#
#          Camera (MP)  Battery Capacity (mAh)  Price ($)
# 3     64 + 8 + 5 + 2                    5020        279
# ...

# %%
df.loc[df['Brand'] == 'Xiaomi', ['Brand', 'Model', 'Price ($)']]
# Out:
#       Brand                  Model  Price ($)
# 3    Xiaomi      Redmi Note 10 Pro        279
# 7    Xiaomi            Poco X3 Pro        249
# 15   Xiaomi       Mi 11 Lite 5G NE        329
# 20   Xiaomi         Redmi 10 Prime        179
# 24   Xiaomi  Redmi Note 10 Pro Max        279
# ..      ...                    ...        ...
# 380  Xiaomi               Redmi 9C        119
# 386  Xiaomi      Redmi Note 10 Pro        329
# 389  Xiaomi               Redmi 9T        199
# 397  Xiaomi                Poco M3        149
# 403  Xiaomi          Mi 10 Lite 5G        349
#
# [67 rows x 3 columns]

# %%
# Memilih subset DataFrame dengan menggunakan iloc untuk baris ke-5 hingga ke-9 dan kolom ke-1 hingga ke-3
df.iloc[5:10, 1:4]
# Out:
#             Model Storage   RAM
# 5       iPhone 13   128 GB     4
# 6  Galaxy Z Flip3   256 GB     8
# 7     Poco X3 Pro   128 GB     6
# 8   Reno6 Pro+ 5G   128 GB     8
# 9        X70 Pro+   256 GB    12

# %%
# Menambahkan kolom 'battery dollar' yang mencerminkan rasio 'Battery Capacity (mAh)' terhadap 'Price ($)'
df['battery dollar'] = df['Battery Capacity (mAh)'] / df['Price ($)']
df
#semakin tinggi nilai battery dollar, berarti semakin besar kapasitasnya tetapi harganya murah
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar
# 0          12 + 12 + 12                    3095        999        3.098098
# ...

# %%
# Menampilkan nilai pertama pada kolom kedua
df.iloc[0,1]
# Out:
# 'iPhone 13 Pro'

# %%
# Mengurutkan DataFrame berdasarkan 'battery dollar' secara descending
df.sort_values(by=['battery dollar'], ascending = False)
# Out:
#         Brand              Model Storage   RAM  Screen Size (inches)  \
# 273    Realme                C11     32GB     2                  6.5
# 216    Realme           C11 2021     32GB     2                 6.52
# 53     Realme          Narzo 50i    32 GB     2                  6.5
# 109  Motorola     Moto E7i Power     32GB     2                  6.5
# 250    Realme           C11 2021     32GB     2                  6.5
# ..        ...                ...      ...   ...                  ...
# 361    Huawei           P40 Pro+      512     8                 6.58
# 338     Apple      iPhone XS Max      256     4                  6.5
# 384     Apple      iPhone 12 Pro      128     6                  6.1
# 369     Apple     iPhone 12 mini      256     4                  5.4
# 373   Samsung  Galaxy Z Fold2 5G      256    12       7.6 (unfolded)
#
#      Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar
# 273   13MP + 2MP                    5000         99       50.505051
# ...

# %% [markdown]
# ## Grouping and Aggregating Data

# %% [markdown]
# Grouping and calculating averages for high-level analysis

# %%
# Mengelompokkan data berdasarkan 'Brand' dengan menghitung rata-rata kapasitas baterai dan harga minimum
df.groupby(['Brand']).agg({'Battery Capacity (mAh)': ['mean'], 'Price ($)': ['min']})
# Out:
#            Battery Capacity (mAh) Price ($)
#                              mean       min
# Brand
# Apple                 2863.900000       399
# Asus                  5000.000000       699
# Blackberry            3500.000000       399
# CAT                   4200.000000       299
# Google                4019.857143       499
# Huawei                4161.666667       199
# LG                    4100.000000       349
# Motorola              5021.739130        99
# Nokia                 4502.857143        99
# OnePlus               4415.000000       299
# Oppo                  4631.339286       139
# Realme                5176.744186        99
# Samsung               4936.708861       129
# Sony                  4500.000000      1299
# Vivo                  4750.000000       139
# Xiaomi                5101.791045       119

# %%
# Mengelompokkan data berdasarkan 'Brand' dan menunjukkan rata-rata harga dan kapasitas baterai
df.groupby(['Brand'])['Battery Capacity (mAh)', 'Price ($)'].mean().sort_values(by=['Price ($)'])
# Out:
# <ipython-input-37-22d62d94a4c2>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Brand'])['Battery Capacity (mAh)', 'Price ($)'].mean().sort_values(by=['Price ($)'])
#             Battery Capacity (mAh)    Price ($)
# Brand
# Realme                 5176.744186   206.906977
# Nokia                  4502.857143   244.714286
# Motorola               5021.739130   278.130435
# Xiaomi                 5101.791045   282.880597
# CAT                    4200.000000   299.000000
# Vivo                   4750.000000   323.000000
# Oppo                   4631.339286   376.142857
# Samsung                4936.708861   480.405063
# Blackberry             3500.000000   499.000000
# LG                     4100.000000   615.666667
# OnePlus                4415.000000   644.333333
# Google                 4019.857143   699.000000
# Apple                  2863.900000   745.666667
# ...

# %%
# Mengelompokkan data berdasarkan 'Brand' dengan menunjukkan rata-rata harga
df.groupby('Brand').agg(average_price = ('Price ($)', 'mean'), sum_price = ('Price ($)', 'sum'))
# Out:
#             average_price  sum_price
# Brand
# Apple          745.666667      22370
# Asus           874.000000       3496
# Blackberry     499.000000       1497
# CAT            299.000000        299
# Google         699.000000       4893
# Huawei         783.166667       9398
# LG             615.666667       1847
# Motorola       278.130435       6397
# Nokia          244.714286       6852
# OnePlus        644.333333       9665
# Oppo           376.142857      21064
# Realme         206.906977       8897
# Samsung        480.405063      37952
# Sony          1299.000000       1299
# Vivo           323.000000      11305
# Xiaomi         282.880597      18953

# %%
# Membuat tabel silang antara 'Brand' dan 'RAM '
pd.crosstab(df['Brand'], df['RAM '])
# Out:
# RAM         2   3   4   5   6   8   12  16
# Brand
# Apple        0  11  14   0   5   0   0   0
# Asus         0   0   0   0   1   3   0   0
# Blackberry   0   0   1   0   2   0   0   0
# CAT          0   1   0   0   0   0   0   0
# Google       0   0   0   0   2   5   0   0
# Huawei       0   0   2   0   0  10   0   0
# LG           0   0   0   0   2   1   0   0
# Motorola     1   2  14   2   3   0   1   0
# Nokia        4   8  10   0   4   2   0   0
# OnePlus      0   0   0   0   3   8   4   0
# Oppo         0   4  13   0  14  15  10   0
# Realme       5   2  20   0   5  11   0   0
# Samsung      1   4  26   0  29  12   6   1
# Sony         0   0   0   0   0   1   0   0
# Vivo         0   5   5   0   4  18   3   0
# Xiaomi       0   1  23   0  33   9   1   0

# %%
# Membuat pivot table dengan indeks 'Brand' dan nilai rata-rata 'Price ($)'
df.pivot_table(index = ['Brand'], values = 'Price ($)', aggfunc = 'mean')
# Out:
#               Price ($)
# Brand
# Apple        745.666667
# Asus         874.000000
# Blackberry   499.000000
# CAT          299.000000
# Google       699.000000
# Huawei       783.166667
# LG           615.666667
# Motorola     278.130435
# Nokia        244.714286
# OnePlus      644.333333
# Oppo         376.142857
# Realme       206.906977
# Samsung      480.405063
# Sony        1299.000000
# Vivo         323.000000
# Xiaomi       282.880597

# %%
df.groupby(['Brand']).agg(avg_price = ('Price ($)', 'mean'))
# Out:
#               avg_price
# Brand
# Apple        745.666667
# Asus         874.000000
# Blackberry   499.000000
# CAT          299.000000
# Google       699.000000
# Huawei       783.166667
# LG           615.666667
# Motorola     278.130435
# Nokia        244.714286
# OnePlus      644.333333
# Oppo         376.142857
# Realme       206.906977
# Samsung      480.405063
# Sony        1299.000000
# Vivo         323.000000
# Xiaomi       282.880597

# %%
df.pivot_table(index = 'Brand', values = 'Price ($)', columns = 'RAM ', aggfunc = 'mean')
# Out:
# RAM            2           3           4      5            6            8   \
# Brand
# Apple         NaN  494.454545  838.285714    NaN  1039.000000          NaN
# Asus          NaN         NaN         NaN    NaN   699.000000   932.333333
# Blackberry    NaN         NaN  399.000000    NaN   549.000000          NaN
# CAT           NaN  299.000000         NaN    NaN          NaN          NaN
# Google        NaN         NaN         NaN    NaN   649.000000   719.000000
# Huawei        NaN         NaN  264.000000    NaN          NaN   887.000000
# LG            NaN         NaN         NaN    NaN   424.000000   999.000000
# Motorola     99.0  184.000000  239.714286  399.0   359.000000          NaN
# Nokia       134.0  142.750000  228.000000    NaN   474.000000   499.000000
# OnePlus       NaN         NaN         NaN    NaN   309.000000   631.500000
# Oppo          NaN  151.500000  190.538462    NaN   272.571429   407.666667
# ...

# %%
df.shape
# Out:
# (407, 9)

# %%
df
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar
# 0          12 + 12 + 12                    3095        999        3.098098
# ...

# %% [markdown]
# ## Data Transformation and Reshaping

# %% [markdown]
# Reshaping data using the melt method

# %%
# Menggabungkan beberapa kolom menjadi satu kolom 'value' dengan 'melt'
df_melt = df.melt(id_vars = ['Brand', 'Model', 'RAM ', 'Storage ', 'Screen Size (inches)', 'Camera (MP)'], \
       var_name = 'nama_kolom', value_name = 'nilai')
df_melt
# Out:
#         Brand              Model  RAM  Storage  Screen Size (inches)  \
# 0       Apple      iPhone 13 Pro     6   128 GB                  6.1
# 1     Samsung   Galaxy S21 Ultra    12   256 GB                  6.8
# 2     OnePlus              9 Pro     8   128 GB                  6.7
# 3      Xiaomi  Redmi Note 10 Pro     6   128 GB                 6.67
# 4      Google            Pixel 6     8   128 GB                  6.4
# ...       ...                ...   ...      ...                  ...
# 1216  Samsung   Galaxy Note20 5G     8      128                  6.7
# 1217   Xiaomi      Mi 10 Lite 5G     6      128                 6.57
# 1218    Apple  iPhone 12 Pro Max     6      128                  6.7
# 1219     Oppo              Reno3     8      128                  6.4
# 1220  Samsung    Galaxy S10 Lite     6      128                  6.7
#
#              Camera (MP)              nama_kolom        nilai
# 0           12 + 12 + 12  Battery Capacity (mAh)  3095.000000
# ...

# %%
# Mengurutkan hasil melt berdasarkan 'Brand'
df_melt.sort_values(by = ['Brand']).head(20)
# Out:
#       Brand              Model  RAM  Storage  Screen Size (inches)  \
# 0     Apple      iPhone 13 Pro     6   128 GB                  6.1
# 469   Apple   iPhone SE (2020)     3    64 GB                  4.7
# 475   Apple          iPhone XR     3    64 GB                  6.1
# 481   Apple          iPhone 11     4   128 GB                  6.1
# 484   Apple          iPhone 13     4    128GB                  6.1
# 1147  Apple   iPhone SE (2020)     3       64                  4.7
# 1152  Apple      iPhone XS Max     4      256                  6.5
# 1161  Apple      iPhone 8 Plus     3       64                  5.5
# 891   Apple          iPhone 13     4    128GB                  6.1
# 888   Apple          iPhone 11     4   128 GB                  6.1
# 882   Apple          iPhone XR     3    64 GB                  6.1
# 1169  Apple          iPhone XR     3       64                  6.1
# 876   Apple   iPhone SE (2020)     3    64 GB                  4.7
# ...

# %%
df
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar
# 0          12 + 12 + 12                    3095        999        3.098098
# ...

# %%
df.stack().head(30)
# Out:
# 0  Brand                                  Apple
#    Model                          iPhone 13 Pro
#    Storage                               128 GB
#    RAM                                        6
#    Screen Size (inches)                     6.1
#    Camera (MP)                     12 + 12 + 12
#    Battery Capacity (mAh)                  3095
#    Price ($)                                999
#    battery dollar                      3.098098
# 1  Brand                                Samsung
#    Model                       Galaxy S21 Ultra
#    Storage                               256 GB
#    RAM                                       12
#    Screen Size (inches)                     6.8
#    Camera (MP)               108 + 10 + 10 + 12
#    Battery Capacity (mAh)                  5000
#    Price ($)                               1199
#    battery dollar                      4.170142
# 2  Brand                                OnePlus
#    Model                                  9 Pro
# ...

# %%
# Menumpuk DataFrame untuk membentuk tata letak yang berbeda
df_stacked = df.set_index(['Brand', 'Model', 'RAM ', 'Storage ', 'Screen Size (inches)', 'Camera (MP)']).stack().reset_index()
df_stacked
# Out:
#         Brand             Model  RAM  Storage  Screen Size (inches)  \
# 0       Apple     iPhone 13 Pro     6   128 GB                  6.1
# 1       Apple     iPhone 13 Pro     6   128 GB                  6.1
# 2       Apple     iPhone 13 Pro     6   128 GB                  6.1
# 3     Samsung  Galaxy S21 Ultra    12   256 GB                  6.8
# 4     Samsung  Galaxy S21 Ultra    12   256 GB                  6.8
# ...       ...               ...   ...      ...                  ...
# 1216     Oppo             Reno3     8      128                  6.4
# 1217     Oppo             Reno3     8      128                  6.4
# 1218  Samsung   Galaxy S10 Lite     6      128                  6.7
# 1219  Samsung   Galaxy S10 Lite     6      128                  6.7
# 1220  Samsung   Galaxy S10 Lite     6      128                  6.7
#
#              Camera (MP)                 level_6            0
# 0           12 + 12 + 12  Battery Capacity (mAh)  3095.000000
# ...

# %%
# Mengganti nama kolom yang telah di-stack
df_stacked.rename(columns = {'level_6': 'atribut', 0:'value'})
# Out:
#         Brand             Model  RAM  Storage  Screen Size (inches)  \
# 0       Apple     iPhone 13 Pro     6   128 GB                  6.1
# 1       Apple     iPhone 13 Pro     6   128 GB                  6.1
# 2       Apple     iPhone 13 Pro     6   128 GB                  6.1
# 3     Samsung  Galaxy S21 Ultra    12   256 GB                  6.8
# 4     Samsung  Galaxy S21 Ultra    12   256 GB                  6.8
# ...       ...               ...   ...      ...                  ...
# 1216     Oppo             Reno3     8      128                  6.4
# 1217     Oppo             Reno3     8      128                  6.4
# 1218  Samsung   Galaxy S10 Lite     6      128                  6.7
# 1219  Samsung   Galaxy S10 Lite     6      128                  6.7
# 1220  Samsung   Galaxy S10 Lite     6      128                  6.7
#
#              Camera (MP)                 atribut        value
# 0           12 + 12 + 12  Battery Capacity (mAh)  3095.000000
# ...

# %%
df
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar
# 0          12 + 12 + 12                    3095        999        3.098098
# ...

# %% [markdown]
# ## Data Categorization and Binning

# %% [markdown]
# Creating price categories using quantiles

# %%
# mengkategorisasikan nilai Price menjadi 4 kategori dengan jumlah ukuran yang sama, misal Bronze, Silver, Gold, Platinum
bin_labels = ['Bronze', 'Silver', 'Gold', 'Platinum']
results, bin_edges = pd.qcut(df['Price ($)'], q = 4, labels = bin_labels, retbins = True)

# %%
results
# Out:
# 0      Platinum
# 1      Platinum
# 2      Platinum
# 3        Silver
# 4      Platinum
#          ...
# 402    Platinum
# 403        Gold
# 404    Platinum
# 405        Gold
# 406    Platinum
# Name: Price ($), Length: 407, dtype: category
# Categories (4, object): ['Bronze' < 'Silver' < 'Gold' < 'Platinum']

# %%
bin_edges
# Out:
# array([  99.,  199.,  299.,  499., 1999.])

# %%
results_table = pd.DataFrame(zip(bin_edges, bin_labels), columns =['Threshold', 'Tier'])
results_table
# Out:
#    Threshold      Tier
# 0       99.0    Bronze
# 1      199.0    Silver
# 2      299.0      Gold
# 3      499.0  Platinum

# %%
# Menambahkan kolom 'results' ke DataFrame
df['results'] = results
df
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar  \
# ...

# %%
# Menunjukkan distribusi
df['results'].value_counts()
# Out:
# Bronze      119
# Silver      101
# Platinum     95
# Gold         92
# Name: results, dtype: int64

# %%
# Mengatur batas kategori harga secara manual
bins = [0, 1000, 2000, 3000, 4000, 5000, 10000]
labels = [1, 2, 3, 4, 5, 6]
df['binned_battery'] = pd.cut(df['Battery Capacity (mAh)'], bins = bins, labels = labels)

# %%
df
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar  \
# ...

# %%
# Menunjukkan distribusi kategori kapasitas baterai
df['binned_battery'].value_counts()
# Out:
# 5    268
# 6     66
# 4     52
# 3     16
# 2      5
# 1      0
# Name: binned_battery, dtype: int64

# %% [markdown]
# ## Adding Columns and Using Rank

# %% [markdown]
# Adding a new column and using the rank function on data

# %%
# Menambahkan kolom 'rank_price' yang memberikan peringkat harga
df['rank_price'] = df['Price ($)'].rank(ascending = True)
df
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB     6                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 2    OnePlus              9 Pro   128 GB     8                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 4     Google            Pixel 6   128 GB     8                  6.4
# ..       ...                ...      ...   ...                  ...
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 404    Apple  iPhone 12 Pro Max      128     6                  6.7
# 405     Oppo              Reno3      128     8                  6.4
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar  \
# ...

# %%
# Mengurutkan DataFrame berdasarkan peringkat harga
df.sort_values(by = ['rank_price'])
# Out:
#        Brand                Model Storage   RAM  Screen Size (inches)  \
# 250   Realme             C11 2021     32GB     2                  6.5
# 240    Nokia             C20 Plus     32GB     3                  6.5
# 216   Realme             C11 2021     32GB     2                 6.52
# 53    Realme            Narzo 50i    32 GB     2                  6.5
# 273   Realme                  C11     32GB     2                  6.5
# ..       ...                  ...      ...   ...                  ...
# 57     Apple    iPhone 13 Pro Max   256 GB     6                  6.7
# 87      Sony         Xperia 5 III    128GB     8                  6.1
# 367  Samsung  Galaxy S20 Ultra 5G      512    16                  6.9
# 361   Huawei             P40 Pro+      512     8                 6.58
# 373  Samsung    Galaxy Z Fold2 5G      256    12       7.6 (unfolded)
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar  \
# ...

# %%
# Memilih entri yang memiliki peringkat harga 4.5
df[df['rank_price'] == 4.5]
# Out:
#         Brand           Model Storage   RAM  Screen Size (inches) Camera (MP)  \
# 53     Realme       Narzo 50i    32 GB     2                  6.5      50 + 2
# 107     Nokia        C20 Plus     32GB     3                  6.5   8MP + 2MP
# 109  Motorola  Moto E7i Power     32GB     2                  6.5  13MP + 2MP
# 216    Realme        C11 2021     32GB     2                 6.52   8MP + 2MP
# 240     Nokia        C20 Plus     32GB     3                  6.5   8MP + 2MP
# 250    Realme        C11 2021     32GB     2                  6.5   8MP + 2MP
# 261    Realme             C20     32GB     2                  6.5         8MP
# 273    Realme             C11     32GB     2                  6.5  13MP + 2MP
#
#      Battery Capacity (mAh)  Price ($)  battery dollar results binned_battery  \
# 53                     5000         99       50.505051  Bronze              5
# 107                    4950         99       50.000000  Bronze              5
# ...

# %% [markdown]
# ## Data Selection Using isin

# %% [markdown]
# Selecting data based on specific criteria using the isin method

# %%
# Menyeleksi entri dengan 'Brand' berisi 'Samsung' atau 'Xiaomi'
body = ['Samsung', 'Xiaomi']
df[df['Brand'].isin(body)]
# Out:
#        Brand              Model Storage   RAM  Screen Size (inches)  \
# 1    Samsung   Galaxy S21 Ultra   256 GB    12                  6.8
# 3     Xiaomi  Redmi Note 10 Pro   128 GB     6                 6.67
# 6    Samsung     Galaxy Z Flip3   256 GB     8                  6.7
# 7     Xiaomi        Poco X3 Pro   128 GB     6                 6.67
# 11   Samsung     Galaxy A52s 5G   128 GB     6                  6.5
# ..       ...                ...      ...   ...                  ...
# 397   Xiaomi            Poco M3      128     4                 6.53
# 398  Samsung      Galaxy A52 5G      128     6                  6.5
# 402  Samsung   Galaxy Note20 5G      128     8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128     6                 6.57
# 406  Samsung    Galaxy S10 Lite      128     6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh)  Price ($)  battery dollar  \
# ...
